# %% [markdown]
# <a href="https://colab.research.google.com/github/Anna-Battaglia/MLPNS_ABattaglia/blob/main/ConvolutionalNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow import keras

# %%
plt.rcParams['figure.figsize'] = [10,8]
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gist_gray' #ho settato i colori

# %%
 cd /content/drive/MyDrive/MLPNS2023
# Out:
# /content/drive/MyDrive/MLPNS2023

# %%
ls
# Out:
# kaggleTitanic/  spm-20210427T111354Z-001.zip  wine.data  wine.names

# %%
# !unzip spm-20210427T111354Z-001.zip
# Out:
# Archive:  spm-20210427T111354Z-001.zip
#   inflating: spm/spm_struct_pos.npy
#   inflating: spm/spm_struct_neg.npy
#   inflating: spm/test_good_all.npy
#   inflating: spm/train_good_all.npy
#   inflating: spm/test_bad_all.npy
#   inflating: spm/train_bad_all.npy

# %%
data = np.load('spm/train_good_all.npy')

# %%
data.shape
# Out:
# (1302, 64, 64)

# %%
fig, ax =plt.subplots(2,4,sharex=True, sharey=True)
for ii in range(8):
  ax[ii // 4, ii % 4].imshow(data[ii])

# %%
plt.hist(data.flatten())
# Out:
# (array([ 254226.,  957465., 1143646., 1050540.,  825288.,  338534.,
#          391059.,  151471.,  179803.,   40960.]),
#  array([-1.07775726e-07, -9.55749615e-08, -8.33741970e-08, -7.11734324e-08,
#         -5.89726678e-08, -4.67719032e-08, -3.45711387e-08, -2.23703741e-08,
#         -1.01696095e-08,  2.03115507e-09,  1.42319196e-08]),
#  <BarContainer object of 10 artists>)

# %%
#norm = (D-MIN(D)) / RANGE(D)
norm = (data - data.min(axis=(1, 2), keepdims=True)) / (data.max(axis=(1, 2), keepdims=True) - 
                                                        data.min(axis=(1, 2), keepdims=True))

# %%
norm.min() , norm.max()
# Out:
# (0.0, 1.0)

# %%
pos=np.load('spm/spm_struct_pos.npy')
neg=np.load('spm/spm_struct_neg.npy')

# %%
pos.shape, neg.shape
# Out:
# ((500, 3), (500, 3))

# %%
pos[0]
# Out:
# array([30, 25, 51])

# %%
pos.max(axis=0)
# Out:
# array([  62,   62, 1300])

# %%
plt.imshow(norm[pos[0][2]])
plt.plot(pos[0][1], pos[0][0],'o')

# %%
wid = 10
stmp_pos = []
for ii in range(pos.shape[0]):
  trow, tcol, tind = pos[ii]
  if (trow > wid) & (trow < 64 - wid) & (tcol > wid) & (tcol < 64 - wid):
    stmp_pos.append(norm[tind, trow-wid:trow+wid, tcol-wid:tcol+wid,])

stmp_pos = np.array(stmp_pos)

# %%
stmp_pos.shape
# Out:
# (389, 20, 20)

# %%
pos.shape[0]
# Out:
# 500

# %%
wid = 10
stmp_neg = []
for ii in range(pos.shape[0]):
  trow, tcol, tind = neg[ii]
  if (trow > wid) & (trow < 64 - wid) & (tcol > wid) & (tcol < 64 - wid):
    stmp_neg.append(norm[tind, trow-wid:trow+wid, tcol-wid:tcol+wid,])

stmp_neg = np.array(stmp_neg)

plt.imshow(stmp_neg[0])

# %%
# plot  positive examples
fig, ax = plt.subplots(10, 10)
for ii in range(100):
    ax[ii // 10, ii % 10].imshow(stmp_pos[ii])
    ax[ii // 10, ii % 10].axis("off")

# %%
# plot  negative examples
fig, ax = plt.subplots(10, 10)
for ii in range(100):
    ax[ii // 10, ii % 10].imshow(stmp_neg[ii])
    ax[ii // 10, ii % 10].axis("off")

# %%
feat = np.concatenate((stmp_neg, stmp_pos), axis=0)
targ = np.concatenate((np.zeros(stmp_neg.shape[0]), 
                      np.ones(stmp_pos.shape[0])))

# %%
feat_tr, feat_te, targ_tr, targ_te = train_test_split(feat, targ, random_state=302, shuffle=True)
feat_tr.shape
# Out:
# (655, 20, 20)

# %%
feat_tr=np.expand_dims(feat_tr, axis=3)
feat_te=np.expand_dims(feat_te, axis=3)
feat_tr.shape
# Out:
# (655, 20, 20, 1)

# %% [markdown]
# #ora possiamo creare il NN
# con: \\
# - conv2d 16 neurons \\
# - maxpool2d 2x2\\
# - conv2d 32 neurons \\
# - maxpool2d 2x2\\
# - flatten
# - dense 64 neurons
# - dense 2 neurons (why?): output

# %%
layer1 = keras.layers.Conv2D(16, kernel_size=(5, 5), padding="same", 
                             activation="relu", 
                             input_shape=(2 * wid, 2 * wid, 1), #needed in the first layer only
                             kernel_regularizer=keras.regularizers.l2(0.001))

layer2 = keras.layers.MaxPool2D(2)

layer3 = keras.layers.Conv2D(32, kernel_size=(5, 5), padding="same", 
                             activation="relu", 
                             kernel_regularizer=keras.regularizers.l2(0.001))

layer4 = keras.layers.MaxPool2D(2)

layer5 = keras.layers.Flatten()

layer6 = keras.layers.Dense(64,activation="relu", kernel_regularizer=keras.regularizers.l2(0.001))

layer7 = keras.layers.Dense(2, activation='softmax')

layers = [layer1, layer2, layer3, layer4, layer5, layer6, layer7]
model = keras.Sequential(layers)
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 20, 20, 16)        416
#
#  max_pooling2d_4 (MaxPooling  (None, 10, 10, 16)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 10, 10, 32)        12832
#
#  max_pooling2d_5 (MaxPooling  (None, 5, 5, 32)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 800)               0
#
#  dense_4 (Dense)             (None, 64)                51264
#
#  dense_5 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 64,642
# Trainable params: 64,642
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy', metrics='accuracy')

# %%
history = model.fit(feat_tr, targ_tr, epochs=50,
                    batch_size=50, validation_split=0.1)
# Out:
# Epoch 1/50
# 12/12 [==============================] - 2s 62ms/step - loss: 0.7243 - accuracy: 0.8081 - val_loss: 0.5788 - val_accuracy: 0.8788
# Epoch 2/50
# 12/12 [==============================] - 0s 38ms/step - loss: 0.5085 - accuracy: 0.9117 - val_loss: 0.3756 - val_accuracy: 0.9242
# Epoch 3/50
# 12/12 [==============================] - 0s 38ms/step - loss: 0.3585 - accuracy: 0.9253 - val_loss: 0.3440 - val_accuracy: 0.9091
# Epoch 4/50
# 12/12 [==============================] - 0s 37ms/step - loss: 0.3090 - accuracy: 0.9168 - val_loss: 0.2946 - val_accuracy: 0.8939
# Epoch 5/50
# 12/12 [==============================] - 0s 39ms/step - loss: 0.2567 - accuracy: 0.9440 - val_loss: 0.2729 - val_accuracy: 0.8939
# Epoch 6/50
# 12/12 [==============================] - 0s 38ms/step - loss: 0.2153 - accuracy: 0.9491 - val_loss: 0.2300 - val_accuracy: 0.9242
# Epoch 7/50
# 12/12 [==============================] - 0s 39ms/step - loss: 0.2007 - accuracy: 0.9610 - val_loss: 0.2698 - val_accuracy: 0.9394
# Epoch 8/50
# 12/12 [==============================] - 0s 37ms/step - loss: 0.2053 - accuracy: 0.9542 - val_loss: 0.2998 - val_accuracy: 0.9242
# Epoch 9/50
# 12/12 [==============================] - 0s 37ms/step - loss: 0.1875 - accuracy: 0.9677 - val_loss: 0.2128 - val_accuracy: 0.9394
# Epoch 10/50
# 12/12 [==============================] - 0s 36ms/step - loss: 0.1477 - accuracy: 0.9864 - val_loss: 0.2204 - val_accuracy: 0.9394
# Epoch 11/50
# 12/12 [==============================] - 0s 37ms/step - loss: 0.1344 - accuracy: 0.9881 - val_loss: 0.1756 - val_accuracy: 0.9394
# Epoch 12/50
# 12/12 [==============================] - 0s 39ms/step - loss: 0.1247 - accuracy: 0.9881 - val_loss: 0.1648 - val_accuracy: 0.9394
# Epoch 13/50
# 12/12 [==============================] - 1s 66ms/step - loss: 0.1179 - accuracy: 0.9898 - val_loss: 0.1665 - val_accuracy: 0.9394
# Epoch 14/50
# 12/12 [==============================] - 1s 67ms/step - loss: 0.1119 - accuracy: 0.9915 - val_loss: 0.1667 - val_accuracy: 0.9545
# Epoch 15/50
# 12/12 [==============================] - 1s 75ms/step - loss: 0.1077 - accuracy: 0.9932 - val_loss: 0.1648 - val_accuracy: 0.9545
# Epoch 16/50
# 12/12 [==============================] - 1s 69ms/step - loss: 0.1105 - accuracy: 0.9881 - val_loss: 0.1711 - val_accuracy: 0.9545
# Epoch 17/50
# 12/12 [==============================] - 1s 70ms/step - loss: 0.0978 - accuracy: 0.9949 - val_loss: 0.1535 - val_accuracy: 0.9697
# Epoch 18/50
# 12/12 [==============================] - 1s 67ms/step - loss: 0.0986 - accuracy: 0.9949 - val_loss: 0.1536 - val_accuracy: 0.9697
# Epoch 19/50
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0972 - accuracy: 0.9932 - val_loss: 0.1339 - val_accuracy: 0.9697
# Epoch 20/50
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0923 - accuracy: 0.9949 - val_loss: 0.1855 - val_accuracy: 0.9394
# Epoch 21/50
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0940 - accuracy: 0.9949 - val_loss: 0.1375 - val_accuracy: 0.9545
# Epoch 22/50
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0874 - accuracy: 0.9966 - val_loss: 0.1320 - val_accuracy: 0.9697
# Epoch 23/50
# 12/12 [==============================] - 0s 38ms/step - loss: 0.0886 - accuracy: 0.9949 - val_loss: 0.1244 - val_accuracy: 0.9697
# Epoch 24/50
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0818 - accuracy: 0.9983 - val_loss: 0.1528 - val_accuracy: 0.9545
# Epoch 25/50
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0855 - accuracy: 0.9932 - val_loss: 0.1334 - val_accuracy: 0.9697
# Epoch 26/50
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0902 - accuracy: 0.9881 - val_loss: 0.1600 - val_accuracy: 0.9545
# Epoch 27/50
# 12/12 [==============================] - 0s 37ms/step - loss: 0.1061 - accuracy: 0.9847 - val_loss: 0.1549 - val_accuracy: 0.9545
# Epoch 28/50
# 12/12 [==============================] - 0s 40ms/step - loss: 0.0881 - accuracy: 0.9949 - val_loss: 0.1638 - val_accuracy: 0.9545
# Epoch 29/50
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0866 - accuracy: 0.9915 - val_loss: 0.1561 - val_accuracy: 0.9697
# Epoch 30/50
# 12/12 [==============================] - 0s 38ms/step - loss: 0.0809 - accuracy: 0.9966 - val_loss: 0.1587 - val_accuracy: 0.9697
# Epoch 31/50
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0772 - accuracy: 0.9983 - val_loss: 0.1186 - val_accuracy: 0.9697
# Epoch 32/50
# 12/12 [==============================] - 0s 39ms/step - loss: 0.0731 - accuracy: 0.9966 - val_loss: 0.1387 - val_accuracy: 0.9697
# Epoch 33/50
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0735 - accuracy: 0.9966 - val_loss: 0.1328 - val_accuracy: 0.9697
# Epoch 34/50
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0769 - accuracy: 0.9949 - val_loss: 0.1699 - val_accuracy: 0.9394
# Epoch 35/50
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0801 - accuracy: 0.9915 - val_loss: 0.1487 - val_accuracy: 0.9697
# Epoch 36/50
# 12/12 [==============================] - 0s 38ms/step - loss: 0.0687 - accuracy: 0.9966 - val_loss: 0.0929 - val_accuracy: 0.9848
# Epoch 37/50
# 12/12 [==============================] - 1s 45ms/step - loss: 0.0682 - accuracy: 0.9966 - val_loss: 0.1046 - val_accuracy: 0.9697
# Epoch 38/50
# 12/12 [==============================] - 1s 46ms/step - loss: 0.0655 - accuracy: 0.9983 - val_loss: 0.1220 - val_accuracy: 0.9697
# Epoch 39/50
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0626 - accuracy: 1.0000 - val_loss: 0.1452 - val_accuracy: 0.9545
# Epoch 40/50
# 12/12 [==============================] - 1s 48ms/step - loss: 0.0638 - accuracy: 0.9966 - val_loss: 0.1095 - val_accuracy: 0.9697
# Epoch 41/50
# 12/12 [==============================] - 1s 69ms/step - loss: 0.0665 - accuracy: 0.9966 - val_loss: 0.1064 - val_accuracy: 0.9697
# Epoch 42/50
# 12/12 [==============================] - 1s 70ms/step - loss: 0.0606 - accuracy: 0.9983 - val_loss: 0.1248 - val_accuracy: 0.9697
# Epoch 43/50
# 12/12 [==============================] - 1s 69ms/step - loss: 0.0588 - accuracy: 0.9983 - val_loss: 0.1293 - val_accuracy: 0.9697
# Epoch 44/50
# 12/12 [==============================] - 1s 68ms/step - loss: 0.0579 - accuracy: 0.9983 - val_loss: 0.1096 - val_accuracy: 0.9697
# Epoch 45/50
# 12/12 [==============================] - 1s 70ms/step - loss: 0.0566 - accuracy: 0.9983 - val_loss: 0.1014 - val_accuracy: 0.9697
# Epoch 46/50
# 12/12 [==============================] - 1s 54ms/step - loss: 0.0561 - accuracy: 0.9983 - val_loss: 0.0972 - val_accuracy: 0.9697
# Epoch 47/50
# 12/12 [==============================] - 0s 38ms/step - loss: 0.0538 - accuracy: 1.0000 - val_loss: 0.1255 - val_accuracy: 0.9697
# Epoch 48/50
# 12/12 [==============================] - 0s 38ms/step - loss: 0.0541 - accuracy: 0.9983 - val_loss: 0.1082 - val_accuracy: 0.9697
# Epoch 49/50
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0523 - accuracy: 1.0000 - val_loss: 0.0968 - val_accuracy: 0.9697
# Epoch 50/50
# 12/12 [==============================] - 0s 37ms/step - loss: 0.0539 - accuracy: 0.9983 - val_loss: 0.1028 - val_accuracy: 0.9697

# %%
plt.plot(history.history['loss'], label='training')
plt.plot(history.history['val_loss'], label='val')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend();

# %%
plt.plot(history.history['accuracy'], label='training')
plt.plot(history.history['val_accuracy'], label='val')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend();

# %%
loss_tr, acc_tr = model.evaluate(feat_tr, targ_tr)
loss_te, acc_te = model.evaluate(feat_te, targ_te)
print((4*'{:.3f}\t').format(loss_tr, acc_tr, loss_te, acc_te))
# Out:
# 21/21 [==============================] - 0s 16ms/step - loss: 0.0557 - accuracy: 0.9969
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0935 - accuracy: 0.9909
# 0.056	0.997	0.093	0.991
